# %% [markdown]
# # Data Processing

# %% [markdown]
# ----
# Credits for the bulk of the code to *Yaron Blinder, 'Predicting 30-day ICU readmissions from the MIMIC-III database'* <br>
# https://github.com/YaronBlinder/MIMIC-III_readmission <br>
#
# And from: https://github.com/bvanaken/clinical-outcome-prediction/blob/master/tasks/mimic_utils.py

# %%
# Import libraries
import numpy as np
import pandas as pd
import os
import psycopg2
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# PARAMETERS

icu_stays = True # set to TRUE if we want to have only ICU stays
combine_dup = True # True if we want to combine the duplicates
remove_dup = True # True if we later want to remove the shortest note
seq_prio = False # set to True if we want to consider only the top priority code of hospitalization

expanded_def = True # set to True if we want to consider future readmissions and avoid using CMS 

if icu_stays == True:
    icu_folder = 'icu_only'
    if expanded_def:
        icu_folder = 'expanded'
else:
    icu_folder = 'all_hosp'

# %%
path_to_repo = os.path.dirname(os.getcwd())

print(path_to_repo)
# Out:
# C:\Users\luca9\Documents\MIMIC-III Text Mining\mimim_iii_readmission

# %%
path_to_data = os.path.join(path_to_repo,"data", icu_folder,"")
os.makedirs(path_to_data, exist_ok=True) # we create the directory if it does not exist
print(path_to_data)
# Out:
# C:\Users\luca9\Documents\MIMIC-III Text Mining\mimim_iii_readmission\data\expanded\

# %%
# create a database connection
sqluser = 'postgres'
dbname = 'mimic'
schema_name = 'mimiciii'
ps_password = 'postgres'

# Connect to local postgres version of mimic
con = psycopg2.connect(dbname=dbname, user=sqluser, password = ps_password)
cur = con.cursor()

# %%
# SQL query (gets all_data view defined elsewhere)
query = \
"""
select * from note_filter
"""

# %%
# Perform SQL query
cur.execute('SET search_path to ' + schema_name)
df = pd.read_sql_query(query,con)

# %%
if icu_stays == True:
    print("Observations before filtering:{}".format(df.shape))
    df.dropna(axis = 0, subset=["first_careunit","last_careunit"], inplace = True)
    print("Observations after filtering:{}".format(df.shape))
# Out:
# Observations before filtering:(59786, 14)
# Observations after filtering:(58824, 14)

# %% [markdown]
# Eliminate all errors within discharge notes.

# %%
df = df[df.iserror != None]
# and drop the column since it won't be needed
df.drop('iserror', axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58824 entries, 0 to 59785
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   subject_id      58824 non-null  int64
#  1   hadm_id         58824 non-null  int64
#  2   admittime       58824 non-null  datetime64[ns]
#  3   dischtime       58824 non-null  datetime64[ns]
#  4   deathtime       6387 non-null   datetime64[ns]
#  5   first_careunit  58824 non-null  object
#  6   last_careunit   58824 non-null  object
#  7   age             58824 non-null  float64
#  8   gender          58824 non-null  object
#  9   marital_status  56124 non-null  object
#  10  insurance       58824 non-null  object
#  11  diagnosis       58823 non-null  object
#  12  text            58824 non-null  object
# dtypes: datetime64[ns](3), float64(1), int64(2), object(7)
# memory usage: 6.3+ MB

# %% [markdown]
# We want to delete all the patients who died either during their first readmission or in later readmissions.

# %%
df_clean = df[np.isnat(df['deathtime'])].copy()

# %%
# sort our values by subject id
df_clean.sort_values('subject_id', inplace = True)
# drop deathtime column since we won't need it anymore
df_clean.drop('deathtime', axis = 1, inplace = True)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52437 entries, 47209 to 44853
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   subject_id      52437 non-null  int64
#  1   hadm_id         52437 non-null  int64
#  2   admittime       52437 non-null  datetime64[ns]
#  3   dischtime       52437 non-null  datetime64[ns]
#  4   first_careunit  52437 non-null  object
#  5   last_careunit   52437 non-null  object
#  6   age             52437 non-null  float64
#  7   gender          52437 non-null  object
#  8   marital_status  50308 non-null  object
#  9   insurance       52437 non-null  object
#  10  diagnosis       52436 non-null  object
#  11  text            52437 non-null  object
# dtypes: datetime64[ns](2), float64(1), int64(2), object(7)
# memory usage: 5.2+ MB

# %%
df_clean.reset_index(inplace = True, drop = True)

# %%
df_clean.shape
# Out:
# (52437, 12)

# %% [markdown]
# **ISSUE**: we have some duplicates.

# %%
# remove duplicates and keep the later ones
df_clean = df_clean.sort_values(by=["subject_id", "hadm_id", 'admittime'])
df_clean = df_clean.drop_duplicates(subset=["text"], keep="last")
df_clean.reset_index(inplace = True, drop = True)

# %%
df_clean.shape
# Out:
# (48765, 12)

# %% [markdown]
# Not only duplicates, we have duplicates in terms of subject_id, hamd_id couples.

# %%
df_clean['duplicate'] = df_clean.duplicated(['subject_id','hadm_id'], keep = False)

# %%
df_clean.loc[4, 'text']
# Out:
# 'Name:  [**Known lastname 9900**], [**Known firstname **] C                     Unit No:  [**Numeric Identifier 9993**]\n\nAdmission Date:  [**2167-1-8**]     Discharge Date:  [**2167-1-15**]\n\nDate of Birth:   [**2127-2-27**]     Sex:  F\n\nService:  Cardiac surgery\n\nIf the previously right coronary artery stenosis is a cause\nfor concern or patient morbidity in the future, this lesion\ncan certainly be addressed percutaneously with balloon\nangiography. She will be followed very closely by Dr. [**Last Name (STitle) 677**]\nas an outpatient, and if this lesion does cause her problems,\nthis may be addressed.\n\n\n                          [**Doctor Last Name **] [**Last Name (Prefixes) **], M.D.  [**MD Number(1) 681**]\n\nDictated By:[**Last Name (NamePattern1) 4660**]\n\nMEDQUIST36\n\nD:  [**2167-1-14**]  16:39\nT:  [**2167-1-14**]  18:51\nJOB#:  [**Job Number 9994**]\n'

# %%
df_clean.loc[5, 'text']
# Out:
# 'Admission Date:  [**2167-1-8**]       Discharge Date:  [**2167-1-15**]\n\nDate of Birth:   [**2127-2-27**]       Sex:  F\n\nService:  Cardiac surgery\n\nCHIEF COMPLAINT:  Chest pain.\n\nHISTORY OF PRESENT ILLNESS:  This is a 39-year-old woman with\ndiabetes, hypertension, hyperlipidemia and obesity, with a\none to two months of chest burning with exertion. For the\npast six months, she has been participating in a new vigorous\nexercise program to lose weight. Her symptoms do gradually\nresolve with rest, but they have started to occur now with\nwalking. She does acknowledge that there is associated\nnausea, diaphoresis and shortness of breath. Now recently she\nstarted to get symptoms for the past two days while at rest.\nShe was referred for an outpatient exercise tolerance test,\nwhere she had chest pain and significant EKG changes. She was\nreferred to [**Hospital1 18**] for cardiac catheterization today, which\nrevealed significant left main artery disease. Just prior to\nher transfer to [**Hospital1 18**], she did complain of chest pain and\nback pain at about 7/10 intensity and a nitroglycerin drip\nwas started and she received 5 mg of IV Lopressor and 2 mg of\nIV Ativan, which did resolve her pain. While she was in the\ncath lab, she had an intraaortic balloon pump placed, and now\nshe is not actively complaining of any pain.\n\nREVIEW OF SYSTEMS:  She denies any orthopnea, lower extremity\nedema, but she does acknowledge that she does have\ndysmenorrhea.\n\nPRIOR MEDICAL HISTORY:  She has diabetes mellitus, type 2,\ndiagnosed in [**2157**]. She has been able to control it with diet\nsince [**2166-6-22**]; hypertension and obesity; however, she has\nlost 40 pounds in the last six months.\n\nSHE HAS AN ALLERGY TO SHELLFISH.\n\nMEDICATIONS ON TRANSFERS TO [**Hospital1 18**]:  Atenolol 50 mg a day,\nlisinopril 10 mg a day, Lipitor 20 mg a day, aspirin 325 mg\nonce a day, progesterone, nitroglycerin drip, Lopressor,\nAtivan.\n\nSOCIAL HISTORY:  She does not smoke. She does not use ethanol\nand she does not use cocaine. Her father had a brain tumor.\nHer brother did have coronary artery disease and a myocardial\ninfarction in his late 30s. Her mother has hypertension. She\ndoes have a strong family history for hyperlipidemia.\n\nPHYSICAL EXAMINATION:  The patient is comfortable appearing,\nin no apparent distress. Vital signs: Temperature 99.1, pulse\n72, blood pressure 144/87. Pulse oximetry is 98% on room air.\nHead and neck: PERRLA. EOMI. Anicteric. Mucous membranes\nmoist. Neck supple, no lymphadenopathy, no JVD. Cardiac:\nRegular rate and rhythm. Lungs clear to auscultation\nbilaterally. Abdomen is soft, nontender, nondistended, but\nshe is morbidly obese, positive bowel sounds. Her extremities\nare warm, no edema. She has got 5/5 strength in all\nextremities.\n\nHer laboratories prior to admission from [**Hospital3 1280**] were\nwhite count 7.4, hematocrit of 39.8, platelets 190,000.\nHemoglobin A1c was 7.1. Sodium was 140, potassium 4.1,\nchloride 103, bicarbonate 28, BUN 14, creatinine 0.6. Total\ncholesterol was 307, triglycerides were 79, and HDL was 50.\n\n[**Last Name (STitle) 54218**], which was at [**Hospital3 1280**] (it was not at\n[**Hospital1 18**]), showed diffuse left main and proximal left anterior\ndescending artery stenosis, 60% to 70%, which was ulcerative;\n50% mid LAD stenosis; 50% left circumflex stenosis after OM1;\nmoderate right coronary artery stenosis; a normal ejection\nfraction of 78%; no mitral regurgitation. Note that the right\ncoronary artery stenosis that I am reported is different than\nwhat was actually reported on the initial catheterization\nresults from [**Hospital3 1280**]. This was discussed between Dr. [**Last Name (Prefixes) 411**] and Dr. [**Last Name (STitle) 911**], and was not actually considered to be\n80% as previously reported.\n\nSo this was a woman who was considered to have unstable\nangina but not actively ischemic. She was put on an\nintraaortic balloon pump, follo ...

# %% [markdown]
# **Option 1:** We remove the shortest note, assuming that its information will be contained in the longer discharge note. <br>
# **Option 2:** We merge the two notes, in case they are important addendums.

# %% [markdown]
# We have 37925 unique admission/subject IDs, and we have keys going up to 7 duplicates.

# %%
df_clean['key'] = df_clean.subject_id.astype(str) + '/' + df_clean.hadm_id.astype(str)

# %%
np.unique(df_clean.key.value_counts().values, return_counts = True)
# Out:
# (array([1, 2, 3, 4, 5, 6, 7], dtype=int64),
#  array([37925,  4151,   605,   130,    26,    11,     1], dtype=int64))

# %%
df_clean.duplicated(['subject_id','hadm_id'], keep = False).value_counts()
# Out:
# False    37925
# True     10840
# dtype: int64

# %%
def merge_and_remove_dup(df_clean, combine_dup = True, remove_dup = True):
    """ Function to combine and remove duplicates 
    combine_dup: set to True if we want to combine duplicates text
    remove_dup: set to True if we want then to remove duplicates    
    """
    df_clean = df_clean.sort_values(by=["subject_id", "hadm_id", 'admittime'])
    df_clean['duplicate'] = df_clean.duplicated(['subject_id','hadm_id'], keep = False)
    # CODE TO REMOVE DUPLICATES -> here we are checking what note is the longes
    if combine_dup == False:
        for idx in np.arange(1,df_clean.shape[0]):
            if df_clean.duplicate[idx] == df_clean.duplicate[idx - 1] and df_clean.subject_id[idx] == df_clean.subject_id[idx - 1] and df_clean.hadm_id[idx] == df_clean.hadm_id[idx - 1]:     
                prev_note = len(df_clean.text[idx -1])
                current_note = len(df_clean.text[idx])
                max_lenght = max(prev_note, current_note)
                df_clean.loc[idx, 'duplicate'] = current_note != max_lenght
                df_clean.loc[idx-1, 'duplicate'] = prev_note != max_lenght

    # CODE TO COMBINE DUPLICATES -> here we are combining the two notes
    if combine_dup == True:
        for idx in np.arange(1,df_clean.shape[0]):
            if df_clean.duplicate[idx] == df_clean.duplicate[idx - 1] and df_clean.subject_id[idx] == df_clean.subject_id[idx - 1] and df_clean.hadm_id[idx] == df_clean.hadm_id[idx - 1]:     
                prev_note = len(df_clean.text[idx -1])
                current_note = len(df_clean.text[idx])
                max_lenght = max(prev_note, current_note)
                df_clean.loc[idx, 'duplicate'] = current_note != max_lenght
                df_clean.loc[idx-1, 'duplicate'] = prev_note != max_lenght
                if current_note != max_lenght:
                    df_clean.loc[idx -1, 'text'] = df_clean.text[idx -1] + '\n\n' + df_clean.text[idx]
                elif current_note == max_lenght:
                    df_clean.loc[idx, 'text'] = df_clean.text[idx] + '\n\n' + df_clean.text[idx-1]

    # CODE TO REMOVE DUPLICATES -> here we are removing the shortest notes (need to run this code in both options)
    if remove_dup == True:
        # get the number of actual duplicates
        print('Initial observations: {}'.format(df_clean.shape[0]))
        print(df_clean.duplicate.value_counts())
        # remove the duplicate rows
        df_clean = df_clean.loc[df_clean['duplicate'] == False,:]
        # sort our values by subject id
        df_clean.sort_values('subject_id', inplace = True)
        # drop duplicate column since we won't need it anymore
        df_clean.drop('duplicate', axis = 1, inplace = True)
        # and reset the index
        df_clean.reset_index(inplace = True, drop = True)
        print('Final observations: {}'.format(df_clean.shape[0]))
    return df_clean

# %%
df_clean = merge_and_remove_dup(df_clean, combine_dup = combine_dup, remove_dup = remove_dup)
# Out:
# Initial observations: 48765
# False    43413
# True      5352
# Name: duplicate, dtype: int64
# Final observations: 43413

# %% [markdown]
# There are still some rare instances in which there were was more than a single duplicate, we will thus repeat the process above to fix them.

# %%
df_clean.duplicated(['subject_id','hadm_id'], keep = False).value_counts()
# Out:
# False    42361
# True      1052
# dtype: int64

# %%
df_clean[df_clean.duplicated(['subject_id','hadm_id'], keep = False)].head(20)
# Out:
#      subject_id  hadm_id           admittime           dischtime  \
# 203         214   197273 2188-10-06 23:56:00 2188-11-04 11:40:00
# 204         214   197273 2188-10-06 23:56:00 2188-11-04 11:40:00
# 216         228   167764 2132-10-30 02:16:00 2132-11-10 17:30:00
# 217         228   167764 2132-10-30 02:16:00 2132-11-10 17:30:00
# 218         231   198608 2176-05-14 21:12:00 2176-06-05 15:00:00
# 219         231   198608 2176-05-14 21:12:00 2176-06-05 15:00:00
# 221         231   198608 2176-05-14 21:12:00 2176-06-05 15:00:00
# 311         330   197569 2133-02-27 12:30:00 2133-03-24 17:00:00
# 312         330   197569 2133-02-27 12:30:00 2133-03-24 17:00:00
# 343         362   142749 2112-07-10 02:31:00 2112-07-16 13:45:00
# 344         362   142749 2112-07-10 02:31:00 2112-07-16 13:45:00
# 446         497   152166 2192-07-22 00:28:00 2192-08-29 18:24:00
# 447         497   152166 2192-07-22 00:28:00 2192-08-29 18:24:00
# 461         515   184373 2162-06-12 16:28:00 2162-07-05 14:20:00
# 462         515   184373 2162-06-12 16:28:00 2162-07-05 14:20:00
# 559         634   145911 2116-10-30 21:05:00 2116-12-31 13:00:00
# 560         634   145911 2116-10-30 21:05:00 2116-12-31 13:00:00
# 561         634   145911 2116-10-30 21:05:00 2116-12-31 13:00:00
# 562         634   145911 2116-10-30 21:05:00 2116-12-31 13:00:00
# 576         663   177445 2143-12-27 07:15:00 2144-01-08 12:01:00
#
#     first_careunit last_careunit        age gender marital_status insurance  \
# 203           CSRU          CSRU  63.442860      M        MARRIED   Private
# 204            CCU           CCU  63.442860      M        MARRIED   Private
# 216            CCU           CCU  79.413360      F        WIDOWED  Medicare
# 217            CCU           CCU  79.413360      F        WIDOWED  Medicare
# 218           MICU          MICU  36.731491      M         SINGLE   Private
# 219           MICU          MICU  36.731491      M         SINGLE   Private
# 221           MICU          MICU  36.731491      M         SINGLE   Private
# 311           SICU          SICU  67.718173      M         SINGLE   Private
# 312           SICU          SICU  67.718173      M         SINGLE   Private
# 343           MICU          MICU  85.795459      F        WIDOWED  Medicare
# 344           MICU          MICU  85.795459      F        WIDOWED  Medicare
# 446           MICU          MICU  23.658340      M         SINGLE  Medicaid
# 447           MICU          MICU  23.658340      M         SINGLE  Medicaid
# 461            CCU           CCU  67.997892      M        MARRIED   Private
# 462            CCU           CCU  67.997892      M        MARRIED   Private
# 559           MICU          MICU  62.859360      M        MARRIED   Private
# 560           MICU          MICU  62.859360      M        MARRIED   Private
# 561           MICU          MICU  62.859360      M        MARRIED   Private
# 562           MICU          MICU  62.859360      M        MARRIED   Private
# 576           MICU          MICU  57.625635      F        MARRIED   Private
#
#                                              diagnosis  \
# 203  HYPOXIA,ACUTE CORONARY SYNDROME,HYPOTENSION,AC...
# 204  HYPOXIA,ACUTE CORONARY SYNDROME,HYPOTENSION,AC...
# 216                                  LT FEMUR FRACTURE
# 217                                  LT FEMUR FRACTURE
# 218                                          PNEUMONIA
# 219                                          PNEUMONIA
# 221                                          PNEUMONIA
# 311                          LEFT CAROTID STENOSIS/SDA
# 312                          LEFT CAROTID STENOSIS/SDA
# 343  HYPONATREMIA-R/O MYOCARDIAL INFARCTION-RHABDOM...
# 344  HYPONATREMIA-R/O MYOCARDIAL INFARCTION-RHABDOM...
# 446                                      DRUG OVERDOSE
# 447                                      DRUG OVERDOSE
# 461                 ASCITIES, MITROVALVE REGURGITATION
# 462                 ASCITIES, MITROVALVE REGURGITATION
# 559                    ELEVATED CREATININE-DEHYDRATION
# 560                    ELEVATED CREATININE-DEHYDRATION
# 561                    ELEVATED CREATININE-DEHYDRATION
# 562                    ELEVATED CREATININE-DEHYDRATION
# 576                                      ACHALASIA/SDA
#
#                                                   text         key
# 203  Admission Date:  [**2188-10-6**]       Dischar...  214/197273
# 204  Name:  [**Known lastname 9454**], [**Known fir...  214/197273
# 216  Admission Date:  [**2132-10-30**]       Discha...  228/167764
# 217  Name:  [**Known lastname 9250**], [**Known fir...  228/167764
# 218  Admission Date:  [**2176-5-14**]       Dischar...  231/198608
# 219  Admission Date:  [**2176-5-14**]       Dischar...  231/198608
# 221  Admission Date:  [**2176-5-14**]       Dischar...  231/198608
# 311  Admission Date: [**2133-2-27**]        Dischar...  330/197569
# 312  Name:  [**Known lastname 5057**],[**Known firs...  330/197569
# 343  Admission Date:  [**2112-7-10**]       Dischar...  362/142749
# 344  Admission Date:  [**2112-7-10**]       Dischar...  362/142749
# 446  Admission Date:  [**2192-7-22**]     Discharge...  497/152166
# 447  Name:  [**Known lastname 7936**], [**Known fir...  497/152166
# 461  Admission Date:  [**2162-6-12**]       Dischar...  515/184373
# 462  Admission Date:  [**2162-6-12**]       Dischar...  515/184373
# 559  Name:  [**Known lastname **], [**Known firstna...  634/145911
# 560  Admission Date:  [**2116-10-30**]       Discha...  634/145911
# 561  Name:  [**Known lastname **], [**Known firstna...  634/145911
# 562  Admission Date:  [**2116-10-30**]       Discha...  634/145911
# 576  Admission Date:  [**2143-12-27**]     Discharg...  663/177445

# %%
for i in range(1,5):
    print('Iteration:{}'.format(i))
    df_clean = merge_and_remove_dup(df_clean, combine_dup = combine_dup, remove_dup = remove_dup)
# Out:
# Iteration:1
# Initial observations: 43413
# False    42872
# True       541
# Name: duplicate, dtype: int64
# Final observations: 42872
# Iteration:2
# Initial observations: 42872
# False    42827
# True        45
# Name: duplicate, dtype: int64
# Final observations: 42827
# Iteration:3
# Initial observations: 42827
# False    42825
# True         2
# Name: duplicate, dtype: int64
# Final observations: 42825
# Iteration:4
# Initial observations: 42825
# False    42825
# Name: duplicate, dtype: int64
# Final observations: 42825

# %%
df_clean.shape
# Out:
# (42825, 13)

# %%
df_clean.duplicated(['subject_id','hadm_id'], keep = False).value_counts()
# Out:
# False    42825
# dtype: int64

# %%
np.unique(df_clean.key.value_counts().values, return_counts = True)
# Out:
# (array([1], dtype=int64), array([42825], dtype=int64))

# %%
df_clean.drop('key', axis = 1, inplace = True)

# %% [markdown]
# ## Planned vs Unplanned Readmissions

# %% [markdown]
# We need to distinguish between planned and unplanned readmissions. In order to do so, we will employ the CMS Plannned Readmission Algorithm Version 3.0 (2015 update). Later version were ignored since they switched to ICD-10 codes.
#
# ![Planned Readmission Algorithm](img/planned_readmission.png)
#
# First we will **load the icd codes for both diagnoses and procedures**.

# %%
# SQL query (gets all_data view defined elsewhere)
query_diag = \
"""
select * from icd_diag_data
"""

# SQL query (gets all_data view defined elsewhere)
query_proc = \
"""
select * from icd_proc_data
"""

# %%
# Perform SQL query
cur.execute('SET search_path to ' + schema_name)
diag_icd = pd.read_sql_query(query_diag,con)
proc_icd = pd.read_sql_query(query_proc,con)

# %%
proc_icd.shape
# Out:
# (240095, 6)

# %%
diag_icd.shape
# Out:
# (651047, 6)

# %% [markdown]
# Then we will upload the ICD-9 to CCS conversion tables, since the CMS algorithm uses a combination of ICD-9 codes and general CCS categories.
#
# > Elixhauser A, Steiner C, Palmer L. Clinical Classifications Software (CCS), 2015. U.S. Agency for Healthcare Research and Quality. Available: http://www.hcup-us.ahrq.gov/toolssoftware/ccs/ccs.jsp

# %%
path_to_css = os.path.join(path_to_repo, "Readmission","css_categories","").replace("\\","/")
path_to_ccs_diag = f'{path_to_css}$dxref 2015.csv'
print(path_to_ccs_diag)
# Out:
# C:/Users/luca9/Documents/MIMIC-III Text Mining/mimim_iii_readmission/Readmission/css_categories/$dxref 2015.csv

# %%
ccs_diag = pd.read_csv(r"C:\Users\luca9\Documents\MIMIC-III Text Mining\Readmission\ccs_categories\$dxref 2015.csv", sep = ";")

ccs_proc = pd.read_csv(r"C:\Users\luca9\Documents\MIMIC-III Text Mining\Readmission\ccs_categories\$prref 2015.csv", sep = ";")

# %% [markdown]
# And drop the duplicates.

# %%
print("CCS-Diag: ",ccs_diag['ICD-9-CM CODE'].duplicated().sum())
print("CCS-Proc: ",ccs_proc['ICD-9-CM CODE'].duplicated().sum())
# Out:
# CCS-Diag:  384
# CCS-Proc:  85

# %%
ccs_diag.drop_duplicates(subset = 'ICD-9-CM CODE', inplace = True)
ccs_proc.drop_duplicates(subset = 'ICD-9-CM CODE', inplace = True)

# %% [markdown]
# Then we perform a left-join of the MIMIC-III tables with the CCS ones to fetch the corresponding CCS code.

# %%
diag_icd = pd.merge(diag_icd, ccs_diag, how = 'left', left_on='icd9_code', right_on='ICD-9-CM CODE')
proc_icd = pd.merge(proc_icd, ccs_proc, how = 'left', left_on='icd9_code', right_on='ICD-9-CM CODE')

# %% [markdown]
# Then we import the categories from the Planned Readmission Algorithm.

# %%
path_to_excel = os.path.join(path_to_repo,"cms_planned_readmission","")
print(path_to_excel)
# Out:
# C:\Users\luca9\Documents\MIMIC-III Text Mining\mimim_iii_readmission\cms_planned_readmission\

# %%
xls = pd.ExcelFile(f'{path_to_excel}planned_readmission_algorithm.xlsx')

# %%
step_1 = pd.read_excel(xls, '1')
step_2 = pd.read_excel(xls, '2')
step_3 = pd.read_excel(xls, '3')
step_4 = pd.read_excel(xls, '4')

# %% [markdown]
# We first check how many procedures can be considered as a Planned Readmission (step 1).

# %%
step_1
# Out:
#         Type Codification  Code  \
# 0  Procedure          CCS    64
# 1  Procedure          CCS   105
# 2  Procedure          CCS   134
# 3  Procedure          CCS   135
# 4  Procedure          CCS   176
#
#                                          Description
# 0                             Bone marrow transplant
# 1                                  Kidney transplant
# 2  Cesarean section (Included only in all-payer p...
# 3  Forceps; vacuum; and breech delivery (Included...
# 4                        Other organ transplantation

# %%
proc_icd['Step 1'] = proc_icd['CCS CATEGORY'].isin(list(step_1.Code))

# %%
proc_icd['Step 1'].value_counts()
# Out:
# False    239551
# True        544
# Name: Step 1, dtype: int64

# %% [markdown]
# We first check how many procedures can be considered as a Planned Readmission (step 2).

# %%
step_2
# Out:
#         Type Codification  Code  \
# 0  Diagnosis          CCS    45
# 1  Diagnosis          CCS   194
# 2  Diagnosis          CCS   196
# 3  Diagnosis          CCS   254
#
#                                          Description
# 0                           Maintenance chemotherapy
# 1  Forceps delivery (Included only in all-payer p...
# 2  Normal pregnancy and/or delivery (Included onl...
# 3  Rehabilitation (Includes only V52.0, V52.1, V5...

# %%
diag_icd['Step 2'] = diag_icd['CCS CATEGORY'].isin(list(step_2.Code))

# %%
diag_icd['Step 2'].value_counts()
# Out:
# False    650973
# True         74
# Name: Step 2, dtype: int64

# %% [markdown]
# Then check if the hospitalization includes a potentially planned procedure (step 3).

# %%
step_3
# Out:
#          Type Codification  Code  \
# 0   Procedure          CCS     3
# 1   Procedure          CCS     5
# 2   Procedure          CCS     9
# 3   Procedure          CCS    10
# 4   Procedure          CCS    12
# ..        ...          ...   ...
# 61  Procedure        ICD-9  3818
# 62  Procedure        ICD-9  5503
# 63  Procedure        ICD-9  5504
# 64  Procedure        ICD-9  9426
# 65  Procedure        ICD-9  9427
#
#                                           Description
# 0          Laminectomy; excision intervertebral disc
# 1   Insertion of catheter or spinal stimulator and...
# 2     Other OR therapeutic nervous system procedures
# 3                 Thyroidectomy; partial or complete
# 4             Other therapeutic endocrine procedures
# ..                                                ...
# 61  Endarterectomy leg vessel (from Procedure CCS ...
# 62  Percutaneous nephrostomy with and without frag...
# 63  Percutaneous nephrostomy with and without frag...
# 64  Electroshock therapy (from Procedure CCS 218-P...
# 65  Electroshock therapy (from Procedure CCS 218-P...
#
# [66 rows x 4 columns]

# %%
# we first check by CCS codes
proc_icd['Step 3'] = proc_icd['CCS CATEGORY'].isin(list(step_3.loc[step_3.Codification == "CCS",].Code))

# %%
proc_icd['Step 3'].value_counts()
# Out:
# False    189094
# True      51001
# Name: Step 3, dtype: int64

# %%
# and then for ICD-9 codes
proc_icd['Step 3-ICD'] = proc_icd['icd9_code'].isin(list(step_3.loc[step_3.Codification != "CCS",].Code))

# %%
proc_icd['Step 3-ICD'].value_counts()
# Out:
# False    240095
# Name: Step 3-ICD, dtype: int64

# %%
# we then get the maximum between the two rows - i.e. if any of the two is True, then it could be a planned readmission
proc_icd["Step 3 - def"] = proc_icd[["Step 3", "Step 3-ICD"]].max(axis=1)

# %% [markdown]
# And then check the Step 4 diagnoses.

# %%
# we first check by CCS codes
diag_icd['Step 4'] = diag_icd['CCS CATEGORY'].isin(list(step_4.loc[step_4.Codification == "CCS",].Code))

# %%
diag_icd['Step 4'].value_counts()
# Out:
# False    404892
# True     246155
# Name: Step 4, dtype: int64

# %%
# and then for ICD-9 codes
diag_icd['Step 4-ICD'] = diag_icd['icd9_code'].isin(list(step_4.loc[step_4.Codification != "CCS",].Code))

# %%
diag_icd['Step 4-ICD'].value_counts()
# Out:
# False    651047
# Name: Step 4-ICD, dtype: int64

# %%
# we then get the maximum between the two rows - i.e. if any of the two is True, then it could be an unplanned readmission
diag_icd["Step 4 - def"] = diag_icd[["Step 4", "Step 4-ICD"]].max(axis=1)

# %% [markdown]
# **Option 2:** Consider only the priority code for the hospitalization (*seq_num = 1.0*).

# %%
if seq_prio == True:
    diag_icd = diag_icd[diag_icd.seq_num == 1]
    proc_icd = proc_icd[proc_icd.seq_num == 1]

# %% [markdown]
# Finally we get the unique values out of the procedures and diagnosis. If one procedure/diagnosis of the same Patient/Hospitalization pair is "True", the final dataframe will be "True". The basic assumption is that if out of all the procedures/diagnoses one is a potentially planned one, the whole hospitalization was planned.

# %%
def unstack_planned(df, step):
    """
    Function to get the unique values for each subject/hospitalization
    """
    unstacked = (df.groupby(['subject_id', 'hadm_id'])[step]
        .apply(lambda x: pd.Series(x.max()))
        .unstack())
    unstacked.rename(columns = {0:step}, inplace = True)
    unstacked.reset_index(inplace = True)
    return unstacked

# %%
unstacked_step_1 = unstack_planned(proc_icd, "Step 1")
unstacked_step_2 = unstack_planned(diag_icd, "Step 2")
unstacked_step_3 = unstack_planned(proc_icd, "Step 3 - def")
unstacked_step_4 = unstack_planned(diag_icd, "Step 4 - def")

# %%
unstacked_step_2.shape
# Out:
# (58976, 3)

# %%
unstacked_step_1.shape
# Out:
# (52243, 3)

# %%
df_clean = pd.merge(df_clean, unstacked_step_1, how = 'left', on=['subject_id', 'hadm_id'])
df_clean = pd.merge(df_clean, unstacked_step_2, how = 'left', on=['subject_id', 'hadm_id'])
df_clean = pd.merge(df_clean, unstacked_step_3, how = 'left', on=['subject_id', 'hadm_id'])
df_clean = pd.merge(df_clean, unstacked_step_4, how = 'left', on=['subject_id', 'hadm_id'])

# %% [markdown]
# There are unfortunately missing data in procedures for certain pairs of Patients/Hospitalizations - with consequently missing data on Step 3 and Step 1 of our Planned Readmission Algorithm. We will consider them as unplanned procedures while processing our algorithm.

# %%
df_clean.isnull().sum()
# Out:
# subject_id           0
# hadm_id              0
# admittime            0
# dischtime            0
# first_careunit       0
# last_careunit        0
# age                  0
# gender               0
# marital_status    1633
# insurance            0
# diagnosis            1
# text                 0
# Step 1            5298
# Step 2               0
# Step 3 - def      5298
# Step 4 - def         0
# dtype: int64

# %% [markdown]
# ## Readmissions

# %% [markdown]
# We now move onto calculating the **readmissions**.

# %%
# sort by subject, admission and admission time
df_clean = df_clean.sort_values(by=["subject_id", "admittime", "hadm_id"])
df_clean.reset_index(inplace = True)

# %%
df_clean.head(10)
# Out:
#    index  subject_id  hadm_id           admittime           dischtime  \
# 0      0           3   145834 2101-10-20 19:08:00 2101-10-31 13:58:00
# 1      1           4   185777 2191-03-16 00:28:00 2191-03-23 18:41:00
# 2      2           6   107064 2175-05-30 07:15:00 2175-06-15 16:00:00
# 3      3          11   194540 2178-04-16 06:18:00 2178-05-11 19:00:00
# 4      4          13   143045 2167-01-08 18:43:00 2167-01-15 15:15:00
# 5      6          17   194023 2134-12-27 07:15:00 2134-12-31 16:05:00
# 6      5          17   161087 2135-05-09 14:11:00 2135-05-13 14:40:00
# 7      7          18   188822 2167-10-02 11:18:00 2167-10-04 16:15:00
# 8      8          19   109235 2108-08-05 16:25:00 2108-08-11 11:29:00
# 9      9          20   157681 2183-04-28 09:45:00 2183-05-03 14:45:00
#
#   first_careunit last_careunit         age gender marital_status insurance  \
# 0           MICU          MICU   76.526788      M        MARRIED  Medicare
# 1           MICU          MICU   47.845044      F         SINGLE   Private
# 2           SICU          SICU   65.940670      F        MARRIED  Medicare
# 3           SICU          SICU   50.148292      F        MARRIED   Private
# 4            CCU          CSRU   39.866116      F           None  Medicaid
# 5           CSRU          CSRU   47.454296      F        MARRIED   Private
# 6           CSRU          CSRU   47.819229      F        MARRIED   Private
# 7            CCU           CCU   50.841554      M        MARRIED   Private
# 8          TSICU         TSICU  300.002968      M           None  Medicare
# 9           CSRU          CSRU   75.876833      F        WIDOWED  Medicare
#
#                                            diagnosis  \
# 0                                        HYPOTENSION
# 1                FEVER,DEHYDRATION,FAILURE TO THRIVE
# 2                          CHRONIC RENAL FAILURE/SDA
# 3                                         BRAIN MASS
# 4                            CORONARY ARTERY DISEASE
# 5  PATIENT FORAMEN OVALE\ PATENT FORAMEN OVALE MI...
# 6                               PERICARDIAL EFFUSION
# 7                              HYPOGLYCEMIA;SEIZURES
# 8                                       C-2 FRACTURE
# 9  CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...
#
#                                                 text Step 1  Step 2  \
# 0  Admission Date:  [**2101-10-20**]     Discharg...  False   False
# 1  Admission Date:  [**2191-3-16**]     Discharge...  False   False
# 2  Admission Date: [**2175-5-30**]        Dischar...   True   False
# 3  Admission Date:  [**2178-4-16**]              ...  False   False
# 4  Admission Date:  [**2167-1-8**]       Discharg...  False   False
# 5  Admission Date:  [**2134-12-27**]             ...  False   False
# 6  Admission Date:  [**2135-5-9**]              D...  False   False
# 7  Admission Date:  [**2167-10-2**]              ...  False   False
# 8  Admission Date:  [**2108-8-5**]              D...    NaN   False
# 9  Admission Date:  [**2183-4-28**]       Dischar...  False   False
#
#   Step 3 - def  Step 4 - def
# 0        False          True
# 1        False          True
# 2        False          True
# 3        False         False
# 4         True          True
# 5         True          True
# 6         True          True
# 7        False          True
# 8          NaN          True
# 9         True          True

# %%
# calculate time delta between subsequent readmissions of the same patient 
df_clean['readmit_dt'] = np.zeros(df_clean.shape[0])
df_clean['next_readmit_dt'] = np.zeros(df_clean.shape[0])
df_clean['readmit_last_careunit'] = None
df_clean['adm_num'] = np.zeros(df_clean.shape[0])
df_clean['step_1_readmit'] = None
df_clean['step_2_readmit'] = None
df_clean['step_3_readmit'] = None
df_clean['step_4_readmit'] = None

for idx in np.arange(1,df_clean.shape[0]):
    if df_clean.subject_id[idx] == df_clean.subject_id[idx - 1]:     
        prev_disch = df_clean.dischtime[idx-1]
        curr_adm = df_clean.admittime[idx]
        dt = curr_adm - prev_disch
        dt_hrs_calc = np.round(dt.value/3600.0/1e9,2)

        df_clean.loc[idx,'adm_num'] = df_clean['adm_num'][idx-1] + 1
        df_clean.loc[idx, 'readmit_dt'] = dt_hrs_calc
        df_clean.loc[idx-1, 'next_readmit_dt'] = dt_hrs_calc
        df_clean.loc[idx, 'readmit_last_careunit'] = df_clean['last_careunit'][idx-1]
        
        # we need to check planned/unplanned readmission too
        df_clean.loc[idx-1, 'step_1_readmit'] = df_clean['Step 1'][idx]
        df_clean.loc[idx-1, 'step_2_readmit'] = df_clean['Step 2'][idx]
        df_clean.loc[idx-1, 'step_3_readmit'] = df_clean['Step 3 - def'][idx]
        df_clean.loc[idx-1, 'step_4_readmit'] = df_clean['Step 4 - def'][idx]

# %% [markdown]
# And then we calculate which of these readmissions happen before 30 days.

# %%
# Define threshold in hours
threshold = 30*24

# %%
# Define label column based on threshold
df_clean['future_readmit'] = None
df_clean['future_readmit'] = ['No' if dt == 0.0 else 'Yes' if dt<=threshold else 'No' for dt in df_clean.next_readmit_dt]

# %%
df_clean.head(50)
# Out:
#     index  subject_id  hadm_id           admittime           dischtime  \
# 0       0           3   145834 2101-10-20 19:08:00 2101-10-31 13:58:00
#
# 47     47          71   111944 2164-02-03 22:07:00 2164-02-08 14:00:00
# 48     48          73   194730 2170-12-22 00:12:00 2170-12-26 12:00:00
# 49     49          75   112086 2147-04-05 08:00:00 2147-04-11 14:45:00
#
#    first_careunit last_careunit         age gender marital_status  ...  \
# 0            MICU          MICU   76.526788      M        MARRIED  ...
# 1            MICU          MICU   47.845044      F         SINGLE  ...
# 2            SICU          SICU   65.940670      F        MARRIED  ...
# 3            SICU          SICU   50.148292      F        MARRIED  ...
# 4             CCU          CSRU   39.866116      F           None  ...
# 5            CSRU          CSRU   47.454296      F        MARRIED  ...
# 6            CSRU          CSRU   47.819229      F        MARRIED  ...
# 7             CCU           CCU   50.841554      M        MARRIED  ...
# 8           TSICU         TSICU  300.002968      M           None  ...
# 9            CSRU          CSRU   75.876833      F        WIDOWED  ...
# 10            CCU           CCU   87.439319      M        MARRIED  ...
# 11           MICU          MICU   64.928234      F        MARRIED  ...
# 12           CSRU          CSRU   71.131748      M        MARRIED  ...
# 13           SICU          SICU   75.256447      M        MARRIED  ...
# 14            CCU           CCU   39.017080      M         SINGLE  ...
# 15            CCU           CCU   58.950196      M        MARRIED  ...
# 16            CCU           CCU   72.006057      M         SINGLE  ...
# 17           CSRU          CSRU   74.384386      M        MARRIED  ...
# 18            CCU           CCU  300.002725      M        MARRIED  ...
# 19          TSICU         TSICU   45.513203      M           None  ...
# 20           MICU          MICU   82.394515      M        MARRIED  ...
# 21            CCU           CCU  304.604137      M        MARRIED  ...
# 22           CSRU          CSRU   69.442914      F       DIVORCED  ...
# 23           CSRU          CSRU   69.699821      M        MARRIED  ...
# 24           CSRU          CSRU   69.734110      M        MARRIED  ...
# 25           MICU          MICU   72.728435      M        MARRIED  ...
# 26           MICU          MICU   68.928820      M        MARRIED  ...
# 27            CCU         TSICU   75.941484      M        WIDOWED  ...
# 28           SICU          SICU   56.634882      M         SINGLE  ...
# 29            CCU           CCU   61.167090      M        MARRIED  ...
# 30          TSICU         TSICU   32.769968      M        MARRIED  ...
# 31           CSRU          CSRU   80.184534      M        MARRIED  ...
# 32          TSICU         TSICU   42.404823      M      SEPARATED  ...
# 33           MICU          MICU   73.999607      M         SINGLE  ...
# 34           CSRU          CSRU   80.917042      M        MARRIED  ...
# 35           MICU          MICU   38.122920      M         SINGLE  ...
# 36            CCU           CCU   45.552941      M        MARRIED  ...
# 37            CCU           CCU   64.162321      F        MARRIED  ...
# 38           MICU          MICU   87.094894      F        WIDOWED  ...
# 39           MICU          MICU   54.655848      M        MARRIED  ...
# 40            CCU           CCU   68.773616      M        MARRIED  ...
# 41           MICU          MICU   88.503174      M       DIVORCED  ...
# 42           MICU          MICU   26.682015      F         SINGLE  ...
# 43          TSICU         TSICU   26.564033      M         SINGLE  ...
# 44           SICU          SICU   70.724427      M         SINGLE  ...
# 45           MICU          MICU   41.796063      F         SINGLE  ...
# 46           MICU          MICU   41.851516      F         SINGLE  ...
# 47           MICU          MICU   36.507087      F         SINGLE  ...
# 48            CCU           CCU   57.586500      F        MARRIED  ...
# 49           CSRU          CSRU   76.771930      F        MARRIED  ...
# 35           None            None            None            None
# 36           None            None            None            None
# 37           None            None            None            None
# 38           None            None            None            None
# 39           None            None            None            None
# 40           None            None            None            None
# 41           None            None            None            None
# 42           None            None            None            None
# 43           None            None            None            None
# 44           None            None            None            None
# 45          False           False           False            True
# 46           None            None            None            None
# 47           None            None            None            None
# 48           None            None            None            None
# 49           None            None            None            None
#
#    future_readmit
# 0              No
# 1              No
# 2              No
# 3              No
# 4              No
# 5              No
# 6              No
# 7              No
# 8              No
# 9              No
# 10             No
# 11             No
# 12             No
# 13             No
# 14             No
# 15             No
# 16             No
# 17             No
# 18             No
# 19             No
# 20             No
# 21             No
# 22             No
# 23            Yes
# 24             No
# 25             No
# 26             No
# 27             No
# 28             No
# 29             No
# 30             No
# 31             No
# 32             No
# 33             No
# 34             No
# 35             No
# 36             No
# 37             No
# 38             No
# 39             No
# 40             No
# 41             No
# 42             No
# 43             No
# 44             No
# 45            Yes
# 46             No
# 47             No
# 48             No
# 49             No
#
# [50 rows x 26 columns]

# %%
print ('Value counts:')
print (df_clean.future_readmit.value_counts())
print ('\nValue proportions:')
print (df_clean.future_readmit.value_counts()/df_clean.shape[0])
print ('\nReadmission counts:')
print (df_clean.adm_num.value_counts())
# Out:
# Value counts:
# No     40381
# Yes     2444
# Name: future_readmit, dtype: int64
#
# Value proportions:
# No     0.942931
# Yes    0.057069
# Name: future_readmit, dtype: float64
#
# Readmission counts:
# 0.0     33348
# 1.0      5650
# 2.0      1798
# 3.0       810
# 4.0       416
# 5.0       217
# 6.0       143
# 7.0       100
# 8.0        68
# 9.0        49
# 10.0       36
# 11.0       24
# 12.0       21
# 13.0       18
# 14.0       15
# 15.0       15
# 16.0       12
# 17.0       10
# 18.0        9
# 19.0        8
# 20.0        7
# 21.0        5
# 23.0        5
# 22.0        5
# 24.0        4
# 25.0        4
# 26.0        4
# 27.0        4
# 29.0        3
# 30.0        3
# 28.0        3
# 31.0        2
# 32.0        2
# 33.0        1
# 34.0        1
# 35.0        1
# 36.0        1
# 37.0        1
# 38.0        1
# 39.0        1
# Name: adm_num, dtype: int64

# %% [markdown]
# There is only one case of negative readmission time, however it is mostly due to a mistake in the database. As we can read from the discharge notes, it was discharged and readmitted on the same date.

# %%
df_clean[(df_clean.readmit_dt < 0) | (df_clean.next_readmit_dt < 0)]
# Out:
#       index  subject_id  hadm_id           admittime           dischtime  \
# 4131   4131        5246   119872 2185-11-14 08:36:00 2185-12-21 18:15:00
# 4132   4132        5246   199031 2185-12-02 23:53:00 2185-12-21 18:15:00
#
#      first_careunit last_careunit        age gender marital_status  ...  \
# 4131           MICU          MICU  74.075157      M         SINGLE  ...
# 4132           MICU          MICU  74.126182      M         SINGLE  ...
#
#      Step 4 - def readmit_dt next_readmit_dt readmit_last_careunit  adm_num  \
# 4131         True       0.00         -450.37                  None      0.0
# 4132         True    -450.37            0.00                  MICU      1.0
#
#      step_1_readmit  step_2_readmit  step_3_readmit  step_4_readmit  \
# 4131          False           False           False            True
# 4132           None            None            None            None
#
#      future_readmit
# 4131            Yes
# 4132             No
#
# [2 rows x 26 columns]

# %%
df_clean.text[4131]
  somnolent but arousable\n\nPertinent Results:\n[**2185-12-1**] 05:41AM   PLT COUNT-619*\n[**2185-12-1**] 05:41AM   WBC-8.3 RBC-3.31* HGB-9.7* HCT-29.0* MCV-88\nMCH-29.5 MCHC-33.6 RDW-18.8*\n[**2185-12-1**] 05:41AM   CALCIUM-8.9 PHOSPHATE-2.5* MAGNESIUM-1.8\n[**2185-12-1**] 05:41AM   GLUCOSE-82 UREA N-13 CREAT-0.8 SODIUM-145\nPOTASSIUM-3.1* CHLORIDE-101 TOTAL CO2-35* ANION GAP-12\n[**2185-12-2**] 09:30PM   CK-MB-6 cTropnT-0.15*\n[**2185-12-2**] 09:30PM   CK(CPK)-295*\n[**2185-12-2**] 10:01PM   TYPE-ART PO2-49* PCO2-49* PH-7.47* TOTAL\nCO2-37* BASE XS-10 INTUBATED-NOT INTUBA COMMENTS-O2 DELIVER\n,\nCTA [**2185-12-3**]:\n1.  Examination limited by patient motion, however, no central\nor segmental pulmonary embolus is identified.  No aortic\ndissection.\n2. Scattered patchy nodular opacities in the right middle and\nlower lung lobes may represent an infectious process.\n3.  Increased interstitial markings at the bilateral lung bases,\nmost likely represent combination of pulmonary edema and\ndependent changes.\n4. Incompletely visualized gallbladder shows multiple foci of\nair within\ngallstones.\n.\nCXR:\nCardiomegaly with patchy bilateral perihilar opacities likely\nrepresenting pulmonary edema. Moderate bilateral pleural\neffusions.\n.\nEEG: IMPRESSION: This is an abnormal EEG in the waking and\ndrowsy states due to the slow and disorganized background, as\nwell as bursts of\ngeneralized delta slowing. This suggests an encephalopathic\npattern,\nwhich may be seen with infections, medications, toxic metabolic\nabnormalities or ischemia. No epileptiform discharges were\nnoted.\n.\n\n[**2185-12-21**] 10:15AM BLOOD WBC-6.6 RBC-3.05* Hgb-9.3* Hct-27.4*\nMCV-90 MCH-30.5 MCHC-34.0 RDW-19.6* Plt Ct-221\n[**2185-12-18**] 10:12AM BLOOD WBC-6.3 RBC-3.00* Hgb-8.9* Hct-26.9*\nMCV-90 MCH-29.8 MCHC-33.2 RDW-19.3* Plt Ct-227\n[**2185-12-2**] 10:20PM B ...

# %% [markdown]
# We have now three types of data:
#
# 1. First hospitalization
# 2. Second hospitalization - Readmission within 30 days
# 3. Second hospitalization - Readmission after 30 days
#
# Since we need to predict the second readmission, we need to drop all the second hospitalization, **even those which happened after 30 days, as they will indeed represent patiens who are suffering of some recurring problems** (*and thus we cannot really use such observations as First hospitalizations*).
#
# We will also drop from Third Hospitalization on for the same reason, even if the second/third/etc. hospitalization is a completely separate event (*i.e. happening after 30 days*).

# %%
if expanded_def:
    df_final = df_clean
else:
    df_final = df_clean.loc[df_clean['adm_num'] == 0,:].copy()

# %%
df_final.head(10)
# Out:
#    index  subject_id  hadm_id           admittime           dischtime  \
# 0      0           3   145834 2101-10-20 19:08:00 2101-10-31 13:58:00
# 1      1           4   185777 2191-03-16 00:28:00 2191-03-23 18:41:00
# 2      2           6   107064 2175-05-30 07:15:00 2175-06-15 16:00:00
# 3      3          11   194540 2178-04-16 06:18:00 2178-05-11 19:00:00
# 4      4          13   143045 2167-01-08 18:43:00 2167-01-15 15:15:00
# 5      6          17   194023 2134-12-27 07:15:00 2134-12-31 16:05:00
# 6      5          17   161087 2135-05-09 14:11:00 2135-05-13 14:40:00
# 7      7          18   188822 2167-10-02 11:18:00 2167-10-04 16:15:00
# 8      8          19   109235 2108-08-05 16:25:00 2108-08-11 11:29:00
# 9      9          20   157681 2183-04-28 09:45:00 2183-05-03 14:45:00
#
#   first_careunit last_careunit         age gender marital_status  ...  \
# 0           MICU          MICU   76.526788      M        MARRIED  ...
# 1           MICU          MICU   47.845044      F         SINGLE  ...
# 2           SICU          SICU   65.940670      F        MARRIED  ...
# 3           SICU          SICU   50.148292      F        MARRIED  ...
# 4            CCU          CSRU   39.866116      F           None  ...
# 5           CSRU          CSRU   47.454296      F        MARRIED  ...
# 6           CSRU          CSRU   47.819229      F        MARRIED  ...
# 7            CCU           CCU   50.841554      M        MARRIED  ...
# 8          TSICU         TSICU  300.002968      M           None  ...
# 9           CSRU          CSRU   75.876833      F        WIDOWED  ...
#
#   Step 4 - def readmit_dt next_readmit_dt readmit_last_careunit  adm_num  \
# 0         True        0.0             0.0                  None      0.0
# 1         True        0.0             0.0                  None      0.0
# 2         True        0.0             0.0                  None      0.0
# 3        False        0.0             0.0                  None      0.0
# 4         True        0.0             0.0                  None      0.0
# 5         True        0.0          3094.1                  None      0.0
# 6         True     3094.1             0.0                  CSRU      1.0
# 7         True        0.0             0.0                  None      0.0
# 8         True        0.0             0.0                  None      0.0
# 9         True        0.0             0.0                  None      0.0
#
#   step_1_readmit  step_2_readmit  step_3_readmit  step_4_readmit  \
# 0           None            None            None            None
# 1           None            None            None            None
# 2           None            None            None            None
# 3           None            None            None            None
# 4           None            None            None            None
# 5          False           False            True            True
# 6           None            None            None            None
# 7           None            None            None            None
# 8           None            None            None            None
# 9           None            None            None            None
#
#   future_readmit
# 0             No
# 1             No
# 2             No
# 3             No
# 4             No
# 5             No
# 6             No
# 7             No
# 8             No
# 9             No
#
# [10 rows x 26 columns]

# %%
print ('Value counts:')
print (df_final.future_readmit.value_counts())
print ('\nValue proportions:')
print (df_final.future_readmit.value_counts()/df_final.shape[0])
print ('\nReadmission counts:')
print (df_final.adm_num.value_counts())
# Out:
# Value counts:
# No     40381
# Yes     2444
# Name: future_readmit, dtype: int64
#
# Value proportions:
# No     0.942931
# Yes    0.057069
# Name: future_readmit, dtype: float64
#
# Readmission counts:
# 0.0     33348
# 1.0      5650
# 2.0      1798
# 3.0       810
# 4.0       416
# 5.0       217
# 6.0       143
# 7.0       100
# 8.0        68
# 9.0        49
# 10.0       36
# 11.0       24
# 12.0       21
# 13.0       18
# 14.0       15
# 15.0       15
# 16.0       12
# 17.0       10
# 18.0        9
# 19.0        8
# 20.0        7
# 21.0        5
# 23.0        5
# 22.0        5
# 24.0        4
# 25.0        4
# 26.0        4
# 27.0        4
# 29.0        3
# 30.0        3
# 28.0        3
# 31.0        2
# 32.0        2
# 33.0        1
# 34.0        1
# 35.0        1
# 36.0        1
# 37.0        1
# 38.0        1
# 39.0        1
# Name: adm_num, dtype: int64

# %%
# we drop columns we will not be using anymore
df_final.drop(['readmit_dt', 'readmit_last_careunit', 'adm_num', 'Step 1', 'Step 2', 'Step 3 - def', 'Step 4 - def'], axis = 1, inplace = True)
df_final.reset_index(inplace = True, drop = True)

# %% [markdown]
# We now need to distinguish between planned and unplanned readmissions using the aformentioned algorithm.

# %%
def planned_admission(row):
    """
    Function to apply the Planned Readmission Algorithm
    """
    if row["step_1_readmit"] == True:
        row['planned_readmit'] = 'Planned'
    elif row["step_2_readmit"] == True:
        row['planned_readmit'] = 'Planned'
    elif row["step_3_readmit"] == True and row["step_4_readmit"] == False:
        row['planned_readmit'] = 'Planned'
    else:
        row['planned_readmit'] = 'Unplanned'
    return row['planned_readmit']

# %%
df_final['planned_readmit'] = df_final.apply(planned_admission, axis = 1)

# %%
if expanded_def == False:
    # replace with "No" for all hospitalizations without readmission
    df_final['planned_readmit'] = np.where(df_final['future_readmit'] == 'No', 'No', df_final['planned_readmit'])

# %%
df_final.planned_readmit.value_counts()
# Out:
# Unplanned    42629
# Planned        196
# Name: planned_readmit, dtype: int64

# %%
df_final.step_1_readmit.value_counts()
# Out:
# False    7887
# True      105
# Name: step_1_readmit, dtype: int64

# %%
df_final.step_2_readmit.value_counts()
# Out:
# False    9461
# True       16
# Name: step_2_readmit, dtype: int64

# %%
df_final.step_3_readmit.value_counts()
# Out:
# False    5598
# True     2394
# Name: step_3_readmit, dtype: int64

# %%
df_final.step_4_readmit.value_counts()
# Out:
# True     9311
# False     166
# Name: step_4_readmit, dtype: int64

# %% [markdown]
# As we can see planned readmissions are not many. In any case, they will be **dropped**.

# %%
# drop readmissions
if expanded_def == False:
    df_final_v02 = df_final[df_final['planned_readmit'] != 'Planned']
else:
    df_final_v02 = df_final.copy()

# %%
# define our target
if expanded_def:
    df_final_v02['target'] = np.where(df_final_v02['future_readmit'] == 'Yes', 1, 0)
else:
    df_final_v02['target'] = np.where(df_final_v02['planned_readmit'] == 'Unplanned', 1, 0)

# %%
df_final_v02.target.value_counts()
# Out:
# 0    40381
# 1     2444
# Name: target, dtype: int64

# %%
df_final_v02.shape
# Out:
# (42825, 21)

# %%
df_final_v02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42825 entries, 0 to 42824
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            42825 non-null  int64
#  1   subject_id       42825 non-null  int64
#  2   hadm_id          42825 non-null  int64
#  3   admittime        42825 non-null  datetime64[ns]
#  4   dischtime        42825 non-null  datetime64[ns]
#  5   first_careunit   42825 non-null  object
#  6   last_careunit    42825 non-null  object
#  7   age              42825 non-null  float64
#  8   gender           42825 non-null  object
#  9   marital_status   41192 non-null  object
#  10  insurance        42825 non-null  object
#  11  diagnosis        42824 non-null  object
#  12  text             42825 non-null  object
#  13  next_readmit_dt  42825 non-null  float64
#  14  step_1_readmit   7992 non-null   object
#  15  step_2_readmit   9477 non-null   object
#  16  step_3_readmit   7992 non-null   object
#  17  step_4_readmit   9477 non-null   object
#  18  future_readmit   42825 non-null  object
#  19  planned_readmit  42825 non-null  object
#  20  target           42825 non-null  int32
# dtypes: datetime64[ns](2), float64(2), int32(1), int64(3), object(13)
# memory usage: 6.7+ MB

# %%
# and save our cleaned dataframe for next usage
# drop columns we do not need anymore
df_final_v02.drop(['step_1_readmit', 'step_2_readmit', 'step_3_readmit', 'step_4_readmit','future_readmit','planned_readmit'], axis = 1, inplace = True)
# need to reset the index
df_final_v02.reset_index(inplace=True, drop = True)
# save our dataset up to now in feather format
df_final_v02.to_feather(f'{path_to_data}df_cleaned')
